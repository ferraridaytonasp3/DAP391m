# %%
from chefboost import Chefboost as chef
import pandas as pd

df = pd.read_csv(r"D:\Data\golf.txt")
df.head()
# Out:
#     Outlook Temp. Humidity    Wind Decision
# 0     Sunny   Hot     High    Weak       No
# 1     Sunny   Hot     High  Strong       No
# 2  Overcast   Hot     High    Weak      Yes
# 3      Rain  Mild     High    Weak      Yes
# 4      Rain  Cool   Normal    Weak      Yes

# %% [markdown]
# **EXAMPLE 1**

# %%
print("ID3 algorithm\n")

#set algorithm
config = {'algorithm': 'ID3'}


#train model on training dataset
print("Train model on traing dataset:")
model = chef.fit(df[:8].copy(), config)

#define x vector for given day
xrow = ['Sunny','Hot','High','Weak']

#make prediction for given day
prediction = chef.predict(model, xrow)
print("Prediction for given day. Should we play? {0}".format(prediction))

c=0
print("\nCompare predictions and expected results on TESTING dataset:")
#prediction on testing data set
for index, instance in df[8:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']  
    print(actual,"-",prediction)
    if(actual==prediction):
        c=c+1
print("Accuracy on TESTING data set:{0}%".format(round(c/df[8:].shape[0],4) ))
# Out:
# ID3 algorithm
#
# Train model on traing dataset:
# 26-01-19 08:13:29 - ID3 tree is going to be built...
# 26-01-19 08:13:30 - -------------------------
# 26-01-19 08:13:30 - finished in 0.20946598052978516 seconds
# 26-01-19 08:13:30 - -------------------------
# 26-01-19 08:13:30 - Evaluate train set
# 26-01-19 08:13:30 - -------------------------
# 26-01-19 08:13:30 - Accuracy: 100.0% on 8 instances
# 26-01-19 08:13:30 - Labels: ['No' 'Yes']
# 26-01-19 08:13:30 - Confusion matrix: [[4, 0], [0, 4]]
# 26-01-19 08:13:30 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
# Prediction for given day. Should we play? No
#
# Compare predictions and expected results on TESTING dataset:
# Yes - No
# Yes - Yes
# Yes - No
# Yes - Yes
# Yes - Yes
# No - No
# Accuracy on TESTING data set:0.6667%
# d:\Python\Lab\outputs\rules\rules.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0] == 'Sunny':
# d:\Python\Lab\outputs\rules\rules.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Rain':
# d:\Python\Lab\outputs\rules\rules.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[3] == 'Weak':
# d:\Python\Lab\outputs\rules\rules.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Overcast':
# d:\Python\Lab\outputs\rules\rules.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[3] == 'Strong':

# %%
print("C4.5 algorithm\n")

#set algorithm
config = {'algorithm': 'C4.5'}
model = chef.fit(df[:8], config)

#define xrow
xrow  = ['Sunny','Hot','High','Weak']

#make single prediction
prediction = chef.predict(model,xrow)

#prediction on test data set
for index, instance in df[8:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']
    
    print(actual,"-",prediction)
print("Accuracy on TESTING data set:{0}%".format(round(c/df[8:].shape[0],4) ))
# Out:
# C4.5 algorithm
#
# 26-01-19 08:13:30 - C4.5 tree is going to be built...
# 26-01-19 08:13:30 - -------------------------
# 26-01-19 08:13:30 - finished in 0.20709514617919922 seconds
# 26-01-19 08:13:30 - -------------------------
# 26-01-19 08:13:30 - Evaluate train set
# 26-01-19 08:13:30 - -------------------------
# 26-01-19 08:13:30 - Accuracy: 100.0% on 8 instances
# 26-01-19 08:13:30 - Labels: ['No' 'Yes']
# 26-01-19 08:13:30 - Confusion matrix: [[4, 0], [0, 4]]
# 26-01-19 08:13:30 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
# Yes - No
# Yes - Yes
# Yes - No
# Yes - Yes
# Yes - Yes
# No - No
# Accuracy on TESTING data set:0.6667%
# d:\Python\Lab\outputs\rules\rules.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0] == 'Sunny':
# d:\Python\Lab\outputs\rules\rules.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Rain':
# d:\Python\Lab\outputs\rules\rules.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[3] == 'Weak':
# d:\Python\Lab\outputs\rules\rules.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Overcast':
# d:\Python\Lab\outputs\rules\rules.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[3] == 'Strong':

# %%
print("CART algorithm\n")

#set algorithm
config = {'algorithm': 'CART'}
model = chef.fit(df[:8], config)

#define single x vector
xrow = ['Sunny','Hot','High','Weak']

#make single prediction
prediction = chef.predict(model, xrow)

#prediction on test data set
print("\nCompare predictions and expected results on TESTING dataset:")
for index, instance in df[8:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']
    
    print(actual,"-",prediction)
print("Accuracy on TESTING data set:{0}%".format(round(c/df[8:].shape[0],4) ))
# Out:
# CART algorithm
#
# 26-01-19 08:13:30 - CART tree is going to be built...
# 26-01-19 08:13:30 - -------------------------
# 26-01-19 08:13:30 - finished in 0.2045574188232422 seconds
# 26-01-19 08:13:30 - -------------------------
# 26-01-19 08:13:30 - Evaluate train set
# 26-01-19 08:13:30 - -------------------------
# 26-01-19 08:13:30 - Accuracy: 100.0% on 8 instances
# 26-01-19 08:13:30 - Labels: ['No' 'Yes']
# 26-01-19 08:13:30 - Confusion matrix: [[4, 0], [0, 4]]
# 26-01-19 08:13:30 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
#
# Compare predictions and expected results on TESTING dataset:
# Yes - No
# Yes - Yes
# Yes - No
# Yes - Yes
# Yes - Yes
# No - No
# Accuracy on TESTING data set:0.6667%
# d:\Python\Lab\outputs\rules\rules.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0] == 'Sunny':
# d:\Python\Lab\outputs\rules\rules.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Rain':
# d:\Python\Lab\outputs\rules\rules.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[3] == 'Weak':
# d:\Python\Lab\outputs\rules\rules.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Overcast':
# d:\Python\Lab\outputs\rules\rules.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[3] == 'Strong':

# %%
import warnings
warnings.filterwarnings('ignore')
from chefboost import Chefboost as chef

print("C5.0 ALGORITHM (Boosting Simulation)")

models = []
for i in range(3):
    config = {'algorithm': 'C4.5'}
    model = chef.fit(df[:8].copy(), config)
    models.append(model)

c = 0
print("\nTesting C5.0 simulation:")
for index, instance in df[8:].iterrows():

    predictions = [chef.predict(model, instance) for model in models]

    final_pred = max(set(predictions), key=predictions.count)

    actual = instance['Decision']
    print(f"{actual} - {final_pred}")

    if actual == final_pred:
        c += 1

accuracy = round(c / df[8:].shape[0] * 100, 2)
print(f"\nC5.0 Simulation Accuracy: {accuracy}%")
# Out:
# C5.0 ALGORITHM (Boosting Simulation)
# 26-01-19 08:53:30 - C4.5 tree is going to be built...
# 26-01-19 08:53:30 - -------------------------
# 26-01-19 08:53:30 - finished in 0.4476776123046875 seconds
# 26-01-19 08:53:30 - -------------------------
# 26-01-19 08:53:30 - Evaluate train set
# 26-01-19 08:53:30 - -------------------------
# 26-01-19 08:53:30 - Accuracy: 100.0% on 8 instances
# 26-01-19 08:53:31 - Labels: ['No' 'Yes']
# 26-01-19 08:53:31 - Confusion matrix: [[4, 0], [0, 4]]
# 26-01-19 08:53:31 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
# 26-01-19 08:53:31 - C4.5 tree is going to be built...
# 26-01-19 08:53:31 - -------------------------
# 26-01-19 08:53:31 - finished in 0.4073352813720703 seconds
# 26-01-19 08:53:31 - -------------------------
# 26-01-19 08:53:31 - Evaluate train set
# 26-01-19 08:53:31 - -------------------------
# 26-01-19 08:53:31 - Accuracy: 100.0% on 8 instances
# 26-01-19 08:53:31 - Labels: ['No' 'Yes']
# 26-01-19 08:53:31 - Confusion matrix: [[4, 0], [0, 4]]
# 26-01-19 08:53:31 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
# 26-01-19 08:53:31 - C4.5 tree is going to be built...
# 26-01-19 08:53:31 - -------------------------
# 26-01-19 08:53:31 - finished in 0.40406155586242676 seconds
# 26-01-19 08:53:31 - -------------------------
# 26-01-19 08:53:31 - Evaluate train set
# 26-01-19 08:53:31 - -------------------------
# 26-01-19 08:53:31 - Accuracy: 100.0% on 8 instances
# 26-01-19 08:53:31 - Labels: ['No' 'Yes']
# 26-01-19 08:53:31 - Confusion matrix: [[4, 0], [0, 4]]
# 26-01-19 08:53:31 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
#
# Testing C5.0 simulation:
# Yes - No
# Yes - Yes
# Yes - No
# Yes - Yes
# Yes - Yes
# No - No
#
# C5.0 Simulation Accuracy: 66.67%

# %% [markdown]
# **EXAMPLE 2**

# %%
from chefboost import Chefboost as chef
import pandas as pd
df=pd.read_csv(r'D:\Data\iris.data')
df = df.sample(frac=1).reset_index(drop=True)
df.head()

print("ID3 algorithm\n")

#set algorithm
config = {'algorithm': 'ID3'}
model = chef.fit(df[:100].copy(), config)

#prediction on test data set
for index, instance in df[100:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']  
    #print(actual,"-",prediction)
    
print("C4.5 algorithm\n")

#set algorithm
config = {'algorithm': 'C4.5'}
model = chef.fit(df[:100].copy(), config)

#prediction on test data set
for index, instance in df[100:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']
    print(actual,"-",prediction)
    
print("CART algorithm\n")

#set algorithm
config = {'algorithm': 'CART'}
model = chef.fit(df[:100].copy(), config)

#prediction on test data set
for index, instance in df[100:].iterrows():
    prediction = chef.predict(model, instance)
    actual=instance['Decision']
    #print(actual,"-",prediction)
# Out:
# ID3 algorithm
#
# 26-01-19 08:16:02 - ID3 tree is going to be built...
# 26-01-19 08:16:03 - -------------------------
# 26-01-19 08:16:03 - finished in 0.6657853126525879 seconds
# 26-01-19 08:16:03 - -------------------------
# 26-01-19 08:16:03 - Evaluate train set
# 26-01-19 08:16:03 - -------------------------
# 26-01-19 08:16:03 - Accuracy: 96.0% on 100 instances
# 26-01-19 08:16:03 - Labels: ['Iris-virginica' 'Iris-setosa' 'Iris-versicolor']
# 26-01-19 08:16:03 - Confusion matrix: [[30, 0, 0], [0, 31, 0], [4, 0, 35]]
# 26-01-19 08:16:03 - Decision Iris-virginica
# 26-01-19 08:16:03 - Accuracy: 96.0
# 26-01-19 08:16:03 - Precision: 100.0%, Recall: 88.2353%, F1: 93.75%
# 26-01-19 08:16:03 - Decision Iris-setosa
# 26-01-19 08:16:03 - Accuracy: 100.0
# 26-01-19 08:16:03 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
# 26-01-19 08:16:03 - Decision Iris-versicolor
# 26-01-19 08:16:03 - Accuracy: 96.0
# 26-01-19 08:16:03 - Precision: 89.7436%, Recall: 100.0%, F1: 94.5946%
# C4.5 algorithm
#
# 26-01-19 08:16:03 - C4.5 tree is going to be built...
# d:\Python\Lab\outputs\rules\rules.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0] == 'Sunny':
# d:\Python\Lab\outputs\rules\rules.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# d:\Python\Lab\outputs\rules\rules.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Rain':
# d:\Python\Lab\outputs\rules\rules.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# d:\Python\Lab\outputs\rules\rules.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[3] == 'Weak':
# d:\Python\Lab\outputs\rules\rules.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   else:
# d:\Python\Lab\outputs\rules\rules.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[3] == 'Strong':
# d:\Python\Lab\outputs\rules\rules.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   else:
# 26-01-19 08:16:04 - -------------------------
# 26-01-19 08:16:04 - finished in 0.6443500518798828 seconds
# 26-01-19 08:16:04 - -------------------------
# 26-01-19 08:16:04 - Evaluate train set
# 26-01-19 08:16:04 - -------------------------
# 26-01-19 08:16:04 - Accuracy: 97.0% on 100 instances
# 26-01-19 08:16:04 - Labels: ['Iris-virginica' 'Iris-setosa' 'Iris-versicolor']
# 26-01-19 08:16:04 - Confusion matrix: [[31, 0, 0], [0, 31, 0], [3, 0, 35]]
# 26-01-19 08:16:04 - Decision Iris-virginica
# 26-01-19 08:16:04 - Accuracy: 97.0
# 26-01-19 08:16:04 - Precision: 100.0%, Recall: 91.1765%, F1: 95.3846%
# 26-01-19 08:16:04 - Decision Iris-setosa
# 26-01-19 08:16:04 - Accuracy: 100.0
# 26-01-19 08:16:04 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
# 26-01-19 08:16:04 - Decision Iris-versicolor
# 26-01-19 08:16:04 - Accuracy: 97.0
# 26-01-19 08:16:04 - Precision: 92.1053%, Recall: 100.0%, F1: 95.8904%
# Iris-setosa - Iris-setosa
# Iris-virginica - Iris-virginica
# Iris-setosa - Iris-setosa
# Iris-setosa - Iris-setosa
# Iris-versicolor - Iris-versicolor
# Iris-setosa - Iris-setosa
# Iris-versicolor - Iris-versicolor
# Iris-versicolor - Iris-versicolor
# Iris-setosa - Iris-setosa
# Iris-virginica - Iris-virginica
# Iris-setosa - Iris-setosa
# Iris-setosa - Iris-setosa
# Iris-virginica - Iris-virginica
# Iris-setosa - Iris-setosa
# Iris-setosa - Iris-setosa
# Iris-virginica - Iris-virginica
# Iris-versicolor - Iris-versicolor
# Iris-virginica - Iris-virginica
# Iris-versicolor - Iris-versicolor
# Iris-virginica - Iris-virginica
# Iris-setosa - Iris-setosa
# Iris-virginica - Iris-virginica
# Iris-versicolor - Iris-versicolor
# Iris-setosa - Iris-setosa
# Iris-setosa - Iris-setosa
# Iris-virginica - Iris-virginica
# Iris-versicolor - Iris-virginica
# Iris-versicolor - Iris-versicolor
# Iris-virginica - Iris-virginica
# Iris-versicolor - Iris-versicolor
# Iris-virginica - Iris-virginica
# Iris-virginica - Iris-virginica
# Iris-setosa - Iris-setosa
# Iris-virginica - Iris-virginica
# Iris-virginica - Iris-virginica
# Iris-setosa - Iris-setosa
# Iris-virginica - Iris-virginica
# Iris-setosa - Iris-setosa
# Iris-setosa - Iris-setosa
# Iris-versicolor - Iris-versicolor
# Iris-versicolor - Iris-versicolor
# Iris-setosa - Iris-setosa
# Iris-versicolor - Iris-virginica
# Iris-setosa - Iris-setosa
# Iris-virginica - Iris-virginica
# Iris-versicolor - Iris-versicolor
# Iris-setosa - Iris-setosa
# Iris-virginica - Iris-virginica
# Iris-versicolor - Iris-virginica
# Iris-versicolor - Iris-versicolor
# CART algorithm
#
# 26-01-19 08:16:04 - CART tree is going to be built...
# d:\Python\Lab\outputs\rules\rules.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0] == 'Sunny':
# d:\Python\Lab\outputs\rules\rules.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# d:\Python\Lab\outputs\rules\rules.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Rain':
# d:\Python\Lab\outputs\rules\rules.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# d:\Python\Lab\outputs\rules\rules.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[3] == 'Weak':
# d:\Python\Lab\outputs\rules\rules.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[3] == 'Strong':
# d:\Python\Lab\outputs\rules\rules.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   else:
# d:\Python\Lab\outputs\rules\rules.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   else:
# 26-01-19 08:16:04 - -------------------------
# 26-01-19 08:16:04 - finished in 0.6237130165100098 seconds
# 26-01-19 08:16:04 - -------------------------
# 26-01-19 08:16:04 - Evaluate train set
# 26-01-19 08:16:04 - -------------------------
# 26-01-19 08:16:04 - Accuracy: 97.0% on 100 instances
# 26-01-19 08:16:04 - Labels: ['Iris-virginica' 'Iris-setosa' 'Iris-versicolor']
# 26-01-19 08:16:04 - Confusion matrix: [[31, 0, 0], [0, 31, 0], [3, 0, 35]]
# 26-01-19 08:16:04 - Decision Iris-virginica
# 26-01-19 08:16:04 - Accuracy: 97.0
# 26-01-19 08:16:04 - Precision: 100.0%, Recall: 91.1765%, F1: 95.3846%
# 26-01-19 08:16:04 - Decision Iris-setosa
# 26-01-19 08:16:04 - Accuracy: 100.0
# 26-01-19 08:16:04 - Precision: 100.0%, Recall: 100.0%, F1: 100.0%
# 26-01-19 08:16:04 - Decision Iris-versicolor
# 26-01-19 08:16:04 - Accuracy: 97.0
# 26-01-19 08:16:04 - Precision: 92.1053%, Recall: 100.0%, F1: 95.8904%
# d:\Python\Lab\outputs\rules\rules.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[0] == 'Sunny':
# d:\Python\Lab\outputs\rules\rules.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# d:\Python\Lab\outputs\rules\rules.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[0] == 'Rain':
# d:\Python\Lab\outputs\rules\rules.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# d:\Python\Lab\outputs\rules\rules.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if obj[3] == 'Weak':
# d:\Python\Lab\outputs\rules\rules.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif obj[3] == 'Strong':
# d:\Python\Lab\outputs\rules\rules.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   else:
# d:\Python\Lab\outputs\rules\rules.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   else:

# %% [markdown]
# **EXAMPLE 3**

# %%
from sklearn.datasets import load_iris
from sklearn import tree
X, y = load_iris(return_X_y=True)
tSize=int(X.shape[0]*0.9)
print(tSize)
X_train=X[0:tSize,:]
y_train=y[0:tSize]

X_test=X[tSize:,:]
y_test=y[tSize:]

clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
y_pred=clf.predict(X_test)



tree.plot_tree(clf) 

from sklearn.metrics import classification_report, confusion_matrix

print("Confusion matrix results:")
print(confusion_matrix(y_test,y_pred))

print("Classification report")
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 2
#       1 from sklearn.datasets import load_iris
# ----> 2 from sklearn import tree
#       3 X, y = load_iris(return_X_y=True)
#       4 tSize=int(X.shape[0]*0.9)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\__init__.py:130, in __getattr__(name)
#     128 def __getattr__(name):
#     129     if name in _submodules:
# --> 130         return _importlib.import_module(f"sklearn.{name}")
#     131     else:
#     132         try:
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python314\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\tree\__init__.py:6
#       1 """Decision tree based models for classification and regression."""
#       3 # Authors: The scikit-learn developers
#       4 # SPDX-License-Identifier: BSD-3-Clause
# ----> 6 from sklearn.tree._classes import (
#       7     BaseDecisionTree,
#       8     DecisionTreeClassifier,
#       9     DecisionTreeRegressor,
#      10     ExtraTreeClassifier,
#      11     ExtraTreeRegressor,
#      12 )
#      13 from sklearn.tree._export import export_graphviz, export_text, plot_tree
#      15 __all__ = [
#      16     "BaseDecisionTree",
#      17     "DecisionTreeClassifier",
#    (...)     23     "plot_tree",
#      24 ]
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\tree\_classes.py:27
#      16 from scipy.sparse import issparse
#      18 from sklearn.base import (
#      19     BaseEstimator,
#      20     ClassifierMixin,
#    (...)     25     is_classifier,
#      26 )
# ---> 27 from sklearn.tree import _criterion, _splitter, _tree
#      28 from sklearn.tree._criterion import Criterion
#      29 from sklearn.tree._splitter import Splitter
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\tree\_criterion.pyx:1, in init sklearn.tree._criterion()
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\tree\_splitter.pyx:1, in init sklearn.tree._splitter()
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\tree\_tree.pyx:1, in init sklearn.tree._tree()
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\neighbors\__init__.py:6
#       1 """The k-nearest neighbors algorithms."""
#       3 # Authors: The scikit-learn developers
#       4 # SPDX-License-Identifier: BSD-3-Clause
# ----> 6 from sklearn.neighbors._ball_tree import BallTree
#       7 from sklearn.neighbors._base import (
#       8     VALID_METRICS,
#       9     VALID_METRICS_SPARSE,
#      10     sort_graph_by_row_values,
#      11 )
#      12 from sklearn.neighbors._classification import (
#      13     KNeighborsClassifier,
#      14     RadiusNeighborsClassifier,
#      15 )
#
# File sklearn/neighbors/_ball_tree.pyx:3, in init sklearn.neighbors._ball_tree()
#
# ImportError: DLL load failed while importing _partition_nodes: An Application Control policy has blocked this file.
